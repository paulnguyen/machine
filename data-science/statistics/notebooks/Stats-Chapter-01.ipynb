# %%
import pandas 
import matplotlib 
 
# %matplotlib inline 
from pandas import *

# %%
# Load the States Data
states_data_set = read_csv('../statsdata/state.csv') 
states_data_set.head()
# Out:
#         State  Population  Murder.Rate Abbreviation
# 0     Alabama     4779736          5.7           AL
# 1      Alaska      710231          5.6           AK
# 2     Arizona     6392017          4.7           AZ
# 3    Arkansas     2915918          5.6           AR
# 4  California    37253956          4.4           CA

# %%
# Calculate Mean on Numeric Columns
states_data_set.mean()
# Out:
# Population     6162876.300
# Murder.Rate          4.066
# dtype: float64

# %%
# mean of the specific column
states_data_set.loc[:,"Population"].mean()
# Out:
# 6162876.3

# %%
states_data_set.plot()

# %%
states_data_set.plot.scatter(x='Population',
                y='Murder.Rate',
                c='DarkBlue')

# %%
states_data_set.plot.bar(x='Population', y='Murder.Rate', rot=0)
